# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('train.csv', index_col='ID')

# %%
train_data.target.unique()
# Out:
# array([1, 0])

# %%
train_data.shape
# Out:
# (114321, 132)

# %%
nonnum_cols = {}
for i in range(1, 132):
    if type(train_data['v' + str(i)].iloc[0]) != np.float64:
        nonnum_cols['v' + str(i)] = train_data['v' + str(i)].unique()

# %%
nonnum_cols
# Out:
# {'v107': array(['E', 'B', 'C', 'D', 'A', 'F', 'G', nan], dtype=object),
#  'v110': array(['B', 'A', 'C'], dtype=object),
#  'v112': array(['O', 'U', 'S', 'J', 'T', 'D', 'I', 'F', 'L', 'M', 'E', 'H', 'N',
#         'R', 'P', 'A', 'B', nan, 'K', 'G', 'C', 'Q', 'V'], dtype=object),
#  'v113': array([nan, 'G', 'X', 'M', 'P', 'S', 'I', 'AC', 'W', 'L', 'B', 'AG', 'AF',
#         'V', 'N', 'T', 'U', 'AE', 'AB', 'C', 'AJ', 'Q', 'A', 'R', 'J', 'Y',
#         'E', 'F', 'AH', 'AI', 'Z', 'D', 'O', 'AD', 'H', 'AK', 'AA'], dtype=object),
#  'v125': array(['AU', 'AF', 'AE', 'CJ', 'Z', 'X', 'BJ', 'BY', 'S', 'E', 'AR', 'AM',
#         'AQ', 'AZ', 'U', 'CD', 'BD', 'CG', 'J', 'N', 'M', 'P', 'AN', 'BW',
#         'AK', 'BO', 'BC', 'BM', 'F', 'AP', 'B', 'L', 'D', 'BL', 'BU', 'R',
#         'K', 'W', 'A', 'CC', 'G', 'V', 'AT', 'BH', 'AC', 'BN', 'BQ', 'Y',
#         'AV', 'H', 'CK', 'Q', 'CB', 'BX', 'BK', 'O', 'BE', 'CL', 'T', 'CE',
# ...

# %%
cont_cols = list(set(train_data.columns) - set(nonnum_cols.keys()))
cont_data = train_data[cont_cols]

# %%
for c in cont_cols:
    sns.distplot(cont_data[cont_data.target == 0][c].dropna(), color='red', bins=15)
    sns.distplot(cont_data[cont_data.target == 1][c].dropna(), color='blue', bins=15)
    plt.show()
# Out:
# /Users/camille/.virtualenvs/ds/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# /Users/camille/.virtualenvs/ds/lib/python3.5/site-packages/statsmodels/nonparametric/kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# /Users/camille/.virtualenvs/ds/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:32: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from scipy.stats import stats

# %%
for c in numerical_cols:
    print(stats.normaltest(num_data[c].dropna()))
# Out:
# NormaltestResult(statistic=2323.1832375168092, pvalue=0.0)
# NormaltestResult(statistic=14320.543921330964, pvalue=0.0)
# NormaltestResult(statistic=961.73896672774936, pvalue=1.4488948187955088e-209)
# NormaltestResult(statistic=46099.591238152207, pvalue=0.0)
# NormaltestResult(statistic=75291.314139351089, pvalue=0.0)
# NormaltestResult(statistic=39233.737379991297, pvalue=0.0)
# NormaltestResult(statistic=50892.357793820076, pvalue=0.0)
# NormaltestResult(statistic=82069.369853840923, pvalue=0.0)
# NormaltestResult(statistic=17577.379309485688, pvalue=0.0)
# NormaltestResult(statistic=32732.314978956401, pvalue=0.0)
# NormaltestResult(statistic=1602.5300891099041, pvalue=0.0)
# NormaltestResult(statistic=37503.582155414479, pvalue=0.0)
# NormaltestResult(statistic=234604.67180984901, pvalue=0.0)
# NormaltestResult(statistic=48233.510316118729, pvalue=0.0)
# NormaltestResult(statistic=37571.226389187141, pvalue=0.0)
# NormaltestResult(statistic=5447.2944990458554, pvalue=0.0)
# ...
